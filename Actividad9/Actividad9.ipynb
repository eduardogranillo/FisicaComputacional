# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardogranillo/FisicaComputacional/blob/master/Actividad9/Actividad9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 18 de Marzo de 2021

# %% [markdown]
# ### Teoría de Estabilidad de Sistemas de Ecuaciones Diferenciales Ordinarias Autónomas.
#
# Estudiaremos los problemas de valor inicial
#
# \begin{equation*}
# \frac{d \vec{x}}{d t} = A \vec{x}, \ \mathrm{con} \ \vec{x}(0)=\vec{x_0}
# \end{equation*}
#
# donde $A$ es una matriz cuadrada constante de dimensión $n \times n$
#
# Si $n=1$, la solución de la ecuación diferencial es
#
# \begin{equation*}
# \vec{x}(t) = x_0 \exp{(At)}
# \end{equation*}
#
# Si $n > 1$, la solución también tendrá la misma forma, pero con $A$ siendo una matriz.
#
# Podemos definir la exponencial de una matriz cuadrada constante A de dimensiones $n \times n$
#
# \begin{equation*}
# \exp(A) = \sum_{k=0}^{\infty} \frac{A^k}{k!}
# \end{equation*}
#
# Esto es similar al desarrollo en Serie de Taylor de $\exp(x)$, alrededor de $x_0=0$.
#
# Vimos en el tema de Álgebra Lineal, que si la matriz es diagonalizable (todos sus eigenvalores son distintos), entonces existe una matriz $P$ formada por los eigenvectores de $A$, tal que $A=P^{-1} \Lambda P$, donde $\Lambda$ es la matriz diagonal formada por los $n$ eigenvalores $(\lambda_1, \lambda_2, \ldots, \lambda_n)$.
#
# También vimos que el cálculo de potencias de la matriz $A$ se simplificaban computacionalmente
#
# \begin{equation*}
# A^k = P^{-1} \Lambda^k P
# \end{equation*}
#
# Si podemos diagonalizar la matriz $A$ ($n$ eigenvalores distintos), y $P = [ x_1 x_2  \ldots  x_n ]$ es un eigenvector de $A$, tendremos
#
# \begin{equation*}
# A = [x_1 x_2 \ldots x_n]^{-1} \ \begin{bmatrix}
# \lambda_1 & 0 & \cdots & 0 \\
# 0 & \lambda_2 & \cdots & 0 \\
# \vdots & \vdots &      & \vdots \\
# 0 & 0 & \cdots & \lambda_n \\
# \end{bmatrix} \ [x_1 x_2 \ldots x_n]
# \end{equation*}
#
# por lo que entonces se tiene que
#
# \begin{equation*}
# At = [x_1 x_2 \ldots x_n]^{-1} \ \begin{bmatrix}
# \lambda_1 t & 0 & \cdots & 0 \\
# 0 & \lambda_2 t & \cdots & 0 \\
# \vdots & \vdots &      & \vdots \\
# 0 & 0 & \cdots & \lambda_n t \\
# \end{bmatrix} \ [x_1 x_2 \ldots x_n]
# \end{equation*}
#
# y calculando la exponencial de $\exp(At)$ sería equivalente a calcular
#
# \begin{equation*}
# \exp(At) = [x_1 x_2 \ldots x_n]^{-1} \ \begin{bmatrix}
# \exp(\lambda_1 t) & 0 & \cdots & 0 \\
# 0 & \exp(\lambda_2 t) & \cdots & 0 \\
# \vdots & \vdots &      & \vdots \\
# 0 & 0 & \cdots & \exp(\lambda_n t) \\
# \end{bmatrix} \ [x_1 x_2 \ldots x_n]
# \end{equation*}
#
# Es fácil ver el comportamento de la solución cuando  $\lim t \rightarrow  \infty$, lo determinan las exponenciales de los eigenvalores.

# %% [markdown]
# **Sistema de ecuaciones lineales homogéneas.**
#
# Supongamos que tenemos el siguiente sistema de ecuaciones diferenciales
#
# \begin{eqnarray*}
# \frac{d x_1}{dt} & = & a x_1 + b x_2 \\
# \frac{d x_2}{dt} & = & c x_1 + d x_2 \\
# \end{eqnarray*}
#
# Si $\vec{x}^T = (x_1, x_2)$, entonces la ecuación anterior se puede escribir como
#
# \begin{equation*}
# \frac{d \vec{x}}{dt} = \frac{d}{dt} \begin{bmatrix}
# x_1 \\ x_2 \end{bmatrix} = A \begin{bmatrix}
# x_1 \\ x_2 \end{bmatrix}, \mathrm{donde} \ A = \begin{bmatrix}
# a & b \\ c & d \end{bmatrix}
# \end{equation*}
#
# Si definimos como $p = \mathrm{Tr}(A) = (a+d)$ y $q=\det (A) = (ad-bc)$
#
# El polinomio característico de $\det(A - \lambda I)$ satisface
#
# \begin{equation*}
# p(\lambda) = \lambda^2 - p \lambda + q
# \end{equation*}
#
# cuyas raíces son
#
# \begin{equation*}
# \lambda_{1,2} = \frac{p \pm \sqrt{p^2 - 4 q}}{2}
# \end{equation*}
#
# donde el discriminante $\Delta = p^2 - 4q = \mathrm{Tr}(A)^2 - 4 \det(A)$ puede ser mayor, igual o menor que cero (es decir, $\lambda$  Real o Compleja).
#
# Se puede ver que $p$ y $q$ satisfacen:
#
# \begin{eqnarray*}
# p & = & \lambda_1 + \lambda_2 \\
# q & = & \lambda_1 \cdot \lambda_2 \\
# \end{eqnarray*}

# %% [markdown]
# **Clasificación de las soluciones**
#
# Para sistema de matrices 2x2, podemos tener 3 posibles categorías:
#
# \begin{eqnarray*}
# A) \begin{bmatrix}
# \lambda & 0 \\
# 0 & \mu
# \end{bmatrix}; B) \begin{bmatrix}
# \lambda & 0 \\
# 1 & \lambda
# \end{bmatrix}; C) \begin{bmatrix}
# a & -b \\
# b & a
# \end{bmatrix}, b\neq0
# \end{eqnarray*}
#
# Estas 3 categorías pueden dividirse en 14 casos de puntos críticos:
#
# **Caso A)** ($\Delta > 0$, eigenvalores reales y distintos)
#
# \begin{equation*}
#  \begin{bmatrix}
# \lambda & 0 \\
# 0 & \mu
# \end{bmatrix}
# \end{equation*}
#
# La solución se puede escribir como
#
# \begin{equation*}
# x(t) = c_1 \exp(\lambda t) \ {v_1} + c_2 \exp(\mu t) \ {v_2}
# \end{equation*}
#
# donde ${v_1}$ y ${v_2}$ son los eigenvectores correspondentes a los eigenvalores $\lambda$ y $\mu$ respectivamente, $c_1$ y $c_2$ constantes.
#
# *Puntos críticos:*
#
# 1.   Punto silla: $\lambda < 0 < \mu$
# 2.   Nodo estable: $\lambda < \mu < 0$
# 3.   Nodo estable: $\lambda=\mu < 0$
# 4.   Nodo inestable: $0 < \lambda < \mu$
# 5.   Nodo inestable: $0 < \lambda = \mu$
# 6.   Nodo degenerado: $\lambda < \mu =0$
# 7.   Nodo degenerado: $0 = \mu < \lambda$
# 8.   Nodo degenerado: $0 = \mu = \lambda$
#
# **Caso B)** ($\Delta = 0$, eigenvalores reales e iguales)
#
# \begin{equation*}
#  \begin{bmatrix}
# \lambda & 0 \\
# 1 & \lambda
# \end{bmatrix}
# \end{equation*}
#
#
# La solución se puede escribir como
#
# \begin{equation*}
# x(t) = [ (c_1 + c_2 t) \ v_1 + c_2 v_2 ] \ \exp(\lambda t)
# \end{equation*}
#
# donde $c_1$ y $c_2$ son constantes y los vectores $v_1$ y $v_2$ satisfacen las ecuaciones
#
# \begin{eqnarray*}
# A v_1 & = & \lambda v_1 \\
# A v_2 & = & \lambda v_1 + v_2
# \end{eqnarray*}
#
# *Puntos críticos:*
#
# 9.  Nodo estable: $\lambda < 0$
# 10. Nodo inestable: $0 < \lambda$
# 11. Nodo degenerado: $\lambda = 0$
#
# **Caso C)** ($\Delta < 0$, eigenvalores complejos)
#
# \begin{equation*}
#  \begin{bmatrix}
# a & -b \\
# b & a
# \end{bmatrix}, b \neq 0
# \end{equation*}
#
# El polinomio característico es
#
# \begin{eqnarray*}
# (a-\lambda)^2 + b^2 & = & 0 \\
# \lambda^2 + a^2 - 2 a \lambda + b^2 & = & 0 \\
# \lambda^2 - 2 a \lambda + (a^2+b^2) & = & 0 \\
# \end{eqnarray*}
#
# cuyas raíces son complejas:
#
# \begin{equation*}
# \lambda_{1,2} = a \pm i b
# \end{equation*}
#
# La solución se puede escribir como
#
# \begin{eqnarray*}
# x(t) & = & c_1 \exp((a+ib)t) \ \ v_1 + c_2 \exp((a-ib)t) \ v_2 \\
# & = & c_1 \exp(at) \exp(ibt) \ v_1 +
# c_2 \exp(at) \exp(-ibt) \ v_2 \\
# & = & [c_1 \exp(ibt) \ v_1 +
# c_2 \exp(-ibt) \ v_2] \ \exp(at) \\
# & = & [c_1 (\cos(bt) + i \sin(bt)) \ v_1 +
# c_2 (\cos(bt) - i \sin(bt)) \ v_2 ] \exp(at) \\
# \end{eqnarray*}
#
# donde $c_1$ y $c_2$ son constantes complejas y los vectores $v_1$ y $v_2$ son vectores complejos en $C^2$.
#
# *Puntos críticos:*
#
# 12. Foco o Espiral estable: $a < 0 < b \ $ ($\mathrm{Tr}(A) < 0$)
# 13. Foco o Espiral inestable: $b < 0 < a \ $  ($\mathrm{Tr}(A) > 0$)
# 14. Centro: $a=0, b>0 \ $  ($\mathrm{Tr}(A) = 0$)
#
# Ver figura la figura de abajo para ver este tipo de soluciones tomada del artículo de [Teoría de Estabilidad de la Wikipedia](https://en.wikipedia.org/wiki/Stability_theory).

# %% [markdown]
# ![Stability_Diagram.png](data:image/png;base64,...)

# %% [markdown]
# **Ejercicios**.
#
# Por favor grafique en el espacio fase una familia de soluciones y determine el tipo de punto crítico de cada uno de los siguientes sistemas de ecuaciones.
#
# **Ejercicio 1.**
#
# \begin{eqnarray*}
# \frac{d x}{d t} & = & y  \\
# \frac{d y}{dt } & = & -x   \\
# \end{eqnarray*}

# %%
# Importamos las bibliotecas a utilizar
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as la
import math as math
from scipy.integrate import odeint, solve_ivp
from scipy import integrate, linalg
from mpl_toolkits import mplot3d


# Matplotlib mostrará los resultados en la Notebook de Jupyter
# %matplotlib inline

# %%
# A = 0 1
#    -1 0

A = np.array([[0,1],[-1,0]])
print('A=',A)
p=np.trace(A)
q=la.det(A)
d=p**2-4*q
print("det(A)/q =",q)
print("Traza(A)/p =",p)
print("Delta =",d)
eigvals, eigvecs = la.eig(A)
print("eigvals =",eigvals)
print("eigvecs =",eigvecs)
# Out:
# A= [[ 0  1]
#  [-1  0]]
# det(A)/q = 1.0
# Traza(A)/p = 0
# Delta = -4.0
# eigvals = [0.+1.j 0.-1.j]
# eigvecs = [[0.70710678+0.j         0.70710678-0.j        ]
#  [0.        +0.70710678j 0.        -0.70710678j]]

# %%
# Punto crítico: Centro
# Definimos la función solución:
def S(c1, c2, t):
  x1 = c1*np.cos(t) + c2*np.sin(t)
  x2 = c2*np.cos(t) - c1*np.sin(t)
  x = [x1, x2]
  return np.array(x)

# Generamos distintas constantes

t = np.linspace(-15, 15, 300)
c1 = np.linspace(-5, 5, 11)
c2 = np.linspace(10, 15, 11)

# Graficamos las soluciones

plt.figure(figsize=(8, 8))
plt.grid();
for i, j in zip(c1, c2):
  sol = np.array(S(i,j,t))
  plt.plot(sol[0,:],sol[1,:])
plt.title('Soluciones particulares del sistema de ecuaciones')
plt.xlabel('x(t)')
plt.ylabel('y(t)')
plt.show();

# %% [markdown]
# **Ejercicio 2.**
#
# \begin{eqnarray*}
# \frac{d x}{d t} & = & y  \\
# \frac{d y}{dt } & = &  x  \\
# \end{eqnarray*}

# %%
# A = 0 1
#     1 0

A = np.array([[0,1],[1,0]])
print('A=',A)
p=np.trace(A)
q=la.det(A)
d=p**2-4*q
print("det(A)/q =",q)
print("Traza(A)/p =",p)
print("Delta =",d)
eigvals, eigvecs = la.eig(A)
print("eigvals =",eigvals)
print("eigvecs =",eigvecs)
# Out:
# A= [[0 1]
#  [1 0]]
# det(A)/q = -1.0
# Traza(A)/p = 0
# Delta = 4.0
# eigvals = [ 1.+0.j -1.+0.j]
# eigvecs = [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %%
# Punto crítico: Punto silla
# Definimos la función solución:
def S(c1, c2, t):
  x1 = c1*np.exp(t) - c2*np.exp(-t)
  x2 = c1*np.exp(t) + c2*np.exp(-t)
  x = [x1, x2]
  return np.array(x)

# Generamos distintas constantes

t = np.linspace(-15, 15, 300)
c1 = np.linspace(-5, 5, 11)
c2 = np.linspace(5, -5, 11)

# Graficamos las soluciones

plt.figure(figsize=(8, 8))
plt.grid();
for i, j in zip(c1, c2):
  sol = np.array(S(i,j,t))
  plt.plot(sol[0,:],sol[1,:])
plt.title('Soluciones particulares del sistema de ecuaciones')
plt.xlabel('x(t)')
plt.ylabel('y(t)')
plt.show();

# %% [markdown]
# **Ejercicio 3.**
#
# \begin{eqnarray*}
# \frac{d^2 x}{d t^2} + \omega_0^2 x & = & 0, \ \omega_0 > 0  \\
# \end{eqnarray*}

# %%
# dv/dt= -w0**2*x

# A = 0 1
#     -w0**2 0

# Definimos un valor para w_0
w0 = 5

A = np.array([[0,1],[-w0**2,0]])
print('A=',A)
p=np.trace(A)
q=la.det(A)
d=p**2-4*q
print("det(A)/q =",q)
print("Traza(A)/p =",p)
print("Delta =",d)
eigvals, eigvecs = la.eig(A)
print("eigvals =",eigvals)
print("eigvecs =",eigvecs)
# Out:
# A= [[  0   1]
#  [-25   0]]
# det(A)/q = 25.0
# Traza(A)/p = 0
# Delta = -100.0
# eigvals = [0.+5.j 0.-5.j]
# eigvecs = [[0.        -0.19611614j 0.        +0.19611614j]
#  [0.98058068+0.j         0.98058068-0.j        ]]

# %%
# Punto crítico: Centro
# Definimos la función solución:
def S(c1, c2, t):
  x1 = c1*np.cos(w0*t) + c2*np.sin(w0*t)
  x2 = c2*w0*np.cos(w0*t) - c1*w0*np.sin(w0*t)
  x = [x1, x2]
  return np.array(x)

# Generamos distintas constantes

t = np.linspace(-15, 15, 300)
c1 = np.linspace(-5, 12, 13)
c2 = np.linspace(10, 15, 13)

# Graficamos las soluciones

plt.figure(figsize=(8, 8))
plt.grid();
for i, j in zip(c1, c2):
  sol = np.array(S(i,j,t))
  plt.plot(sol[0,:],sol[1,:])
plt.title('Soluciones particulares del sistema de ecuaciones')
plt.xlabel('x(t)')
plt.ylabel('y(t)')
plt.xlim(-100, 100)
plt.ylim(-100, 100)
plt.show();

# %% [markdown]
# **Ejercicio 4.**
#
# \begin{eqnarray*}
# \frac{d x}{d t} & = & -2 x  \\
# \frac{d y}{dt } & = &  2 z  \\
# \frac{d z}{dt } & = &  - 2 y  \\
# \end{eqnarray*}

# %%
# A = -2 0 0
#      0 0 2
#      0-2 0

A = np.array([[-2,0,0],[0,0,2],[0,-2,0]])
print('A=',A)
p=np.trace(A)
q=la.det(A)
d=p**2-4*q
print("det(A)/q =",q)
print("Traza(A)/p =",p)
print("Delta =",d)
eigvals, eigvecs = la.eig(A)
print("eigvals =",eigvals)
print("eigvecs =",eigvecs)
# Out:
# A= [[-2  0  0]
#  [ 0  0  2]
#  [ 0 -2  0]]
# det(A)/q = -8.0
# Traza(A)/p = -2
# Delta = 36.0
# eigvals = [ 0.+2.j  0.-2.j -2.+0.j]
# eigvecs = [[ 0.        +0.j          0.        -0.j          1.        +0.j        ]
#  [-0.70710678+0.j         -0.70710678-0.j          0.        +0.j        ]
#  [ 0.        -0.70710678j  0.        +0.70710678j  0.        +0.j        ]]

# %%
# Punto crítico: Centro
# Definimos la función solución:
def S(c1, c2, c3, t):
  x1 = c1*np.exp(-2*t)
  x2 = c2*np.cos(2*t) + c3*np.sin(2*t)
  x3 = -c2*np.sin(2*t) + c3*np.cos(2*t)
  x = [x1, x2, x3]
  return np.array(x)

# Generamos distintas constantes

t = np.linspace(-15, 15, 300)
c1 = np.linspace(-5, 12, 13)
c2 = np.linspace(10, 15, 13)
c3 = np.linspace(5, 10, 13)

# Graficamos las soluciones

plt.figure(figsize=(8, 8))
plt.grid();
ax = plt.axes(projection='3d')
for i, j, k in zip(c1, c2, c3):
  sol = np.array(S(i,j,k,t))
  ax.plot3D(sol[0,:], sol[1,:], sol[2,:])
plt.title('Soluciones particulares del sistema de ecuaciones')
ax.set_xlabel('x(t)')
ax.set_ylabel('y(t)')
ax.set_zlabel('z(t)')
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# **Ejercicio 5.**
#
# \begin{eqnarray*}
# \frac{d x}{d t} & = & - x + z  \\
# \frac{d y}{dt } & = &  3 y  \\
# \frac{d z}{dt } & = &  - x - z \\
# \end{eqnarray*}

# %%
# A = -1 0 1
#      0 3 0
#     -1 0 -1

A = np.array([[-1,0,1],[0,3,0],[-1,0,-1]])
print('A=',A)
p=np.trace(A)
q=la.det(A)
d=p**2-4*q
print("det(A)/q =",q)
print("Traza(A)/p =",p)
print("Delta =",d)
eigvals, eigvecs = la.eig(A)
print("eigvals =",eigvals)
print("eigvecs =",eigvecs)
# Out:
# A= [[-1  0  1]
#  [ 0  3  0]
#  [-1  0 -1]]
# det(A)/q = 6.0
# Traza(A)/p = 1
# Delta = -23.0
# eigvals = [-1.+1.j -1.-1.j  3.+0.j]
# eigvecs = [[0.70710678+0.j         0.70710678-0.j         0.        +0.j        ]
#  [0.        +0.j         0.        -0.j         1.        +0.j        ]
#  [0.        +0.70710678j 0.        -0.70710678j 0.        +0.j        ]]

# %%
fig = plt.figure()
  
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
t=np.linspace(0,100,500)
# defining all 3 axes
for c1 in [1,7]:
  for c2 in [1,7]:
    for c3 in [1,5]:

      x= (c1*np.sin(t)-c2*np.cos(t))*np.exp(-t)
      y = (c1*np.cos(t)+c2*np.sin(t))*np.exp(-t)
      z =c3*np.exp(3*t)
      ax.plot3D(x, y, z)
# plotting
#ax.plot3D(x, y, z)
ax.set_title('Solucion en espacio fase')
plt.xlim(-5,5)
plt.ylim(-5,5)

plt.show()

# %% [markdown]
# Resuelva los siguientes problemas de valor inicial
#
# **Ejercicio 6:**
#
# \begin{eqnarray*}
# \frac{d x}{d t} & = & - x  \\
# \frac{d y}{dt } & = &  x + 2 y  \\
# x(0) = 0, & & y(0) = 3
# \end{eqnarray*}
#
# **Ejercicio 7:**
#
# \begin{eqnarray*}
# \frac{d x}{d t} & = & 2 x + y  \\
# \frac{d y}{dt } & = &  x +  y  \\
# x(1) = 1, & & y(1) = 1
# \end{eqnarray*}
#
# **Ejercicio 8:**
#
# \begin{eqnarray*}
# \frac{d x}{d t} & = & A x  \\
# x(0) & = & (0,3) \\
# A & = & \begin{bmatrix}
# 0 & 3 \\
# 1 & -2 \\
# \end{bmatrix}
# \end{eqnarray*}
#
# **Ejercicio 9:**
#
# \begin{eqnarray*}
# \frac{d x}{d t} & = & A x  \\
# x(0) & = & (0,-b,b) \\
# A & = & \begin{bmatrix}
# 2 & 0 & 0 \\
# 0 & -1 & 0 \\
# 0 & 2 & -3 \\
# \end{bmatrix}
# \end{eqnarray*}

# %% [markdown]
# **Ejercicio 6:**
#
# \begin{eqnarray*}
# \frac{d x}{d t} & = & - x  \\
# \frac{d y}{dt } & = &  x + 2 y  \\
# x(0) = 0, & & y(0) = 3
# \end{eqnarray*}

# %%
# A = -1 0 
#      1 2 

A = np.array([[-1,0],[1,2]])
print('A=',A)
p=np.trace(A)
q=la.det(A)
d=p**2-4*q
print("det(A)/q =",q)
print("Traza(A)/p =",p)
print("Delta =",d)
eigvals, eigvecs = la.eig(A)
print("eigvals =",eigvals)
print("eigvecs =",eigvecs)
# Out:
# A= [[-1  0]
#  [ 1  2]]
# det(A)/q = -2.0
# Traza(A)/p = 1
# Delta = 9.0
# eigvals = [ 2.+0.j -1.+0.j]
# eigvecs = [[ 0.          0.9486833 ]
#  [ 1.         -0.31622777]]

# %%
def dX_dt(X, t=0):
    """ El lado derecho del sistema de ecuaciones """
    return np.array([ -1*X[0] ,
                  X[0]+2*X[1]])
    
# Los puntos críticos del sistema
X_f0 = np.array([     0. ,  0.])

print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')
# En los puntos críticos se anulan las derivadas. 
all(dX_dt(X_f0) == np.zeros(2) )
# Out:
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0.]
# True

# %%
lambda1 = eigvals[0]
lambda2 = eigvals[1]
print('Eigenvalores')
print('lambda1= ', lambda1)
print('lambda2= ', lambda2)
print(' ')
print('Eigenvectores')
v1 = eigvecs[:,0]
v2 = eigvecs[:,1]
print('v1=',v1)
print('v2=',v2)
# Out:
# Eigenvalores
# lambda1=  (2+0j)
# lambda2=  (-1+0j)
#
# Eigenvectores
# v1= [0. 1.]
# v2= [ 0.9486833  -0.31622777]

# %%
t = np.linspace(1, 8,  500)              # Rango de tiempo de integración
X0 = np.array([0, 3])                    # Condiciones iniciales
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
x,y=X.T
plt.plot(x, y, 'r-')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.ylim(0, 10)
plt.xlim(-1, 10)
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# **Ejercicio 7:**
#
# \begin{eqnarray*}
# \frac{d x}{d t} & = & 2 x + y  \\
# \frac{d y}{dt } & = &  x +  y  \\
# x(1) = 1, & & y(1) = 1
# \end{eqnarray*}

# %%
# A = 2 1 
#     1 1 

A = np.array([[2,1],[1,1]])
print('A=',A)
p=np.trace(A)
q=la.det(A)
d=p**2-4*q
print("det(A)/q =",q)
print("Traza(A)/p =",p)
print("Delta =",d)
eigvals, eigvecs = la.eig(A)
print("eigvals =",eigvals)
print("eigvecs =",eigvecs)
# Out:
# A= [[2 1]
#  [1 1]]
# det(A)/q = 1.0
# Traza(A)/p = 3
# Delta = 5.0
# eigvals = [2.61803399+0.j 0.38196601+0.j]
# eigvecs = [[ 0.85065081 -0.52573111]
#  [ 0.52573111  0.85065081]]

# %%
def dX_dt(X, t=1):
    """ El lado derecho del sistema de ecuaciones """
    return np.array([ 2*X[0] + X[1] ,
                  X[0]+X[1]])
    
X_f0=np.array([0.0,  0.0  ])
#Puntos criticos 
all(dX_dt(X_f0) == np.zeros(2) )
# Out:
# True

# %%
t = np.linspace(1, 8,  500)              # Rango de tiempo de integración
X0 = np.array([1, 1])                     # Condiciones iniciales
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
x,y=X.T
plt.plot(x, y, 'orange')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.ylim(0, 10)
plt.xlim(0, 10)
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# **Ejercicio 8:**
#
# \begin{eqnarray*}
# \frac{d x}{d t} & = & A x  \\
# x(0) & = & (0,3) \\
# A & = & \begin{bmatrix}
# 0 & 3 \\
# 1 & -2 \\
# \end{bmatrix}
# \end{eqnarray*}

# %%
# A = 0 3 
#     1 -2 

A = np.array([[0,3],[1,-2]])
print('A=',A)
p=np.trace(A)
q=la.det(A)
d=p**2-4*q
print("det(A)/q =",q)
print("Traza(A)/p =",p)
print("Delta =",d)
eigvals, eigvecs = la.eig(A)
print("eigvals =",eigvals)
print("eigvecs =",eigvecs)
# Out:
# A= [[ 0  3]
#  [ 1 -2]]
# det(A)/q = -3.0
# Traza(A)/p = -2
# Delta = 16.0
# eigvals = [ 1.+0.j -3.+0.j]
# eigvecs = [[ 0.9486833  -0.70710678]
#  [ 0.31622777  0.70710678]]

# %%
def dX_dt(X,t=0):
  return np.array([0*X[0]+3*X[1] , X[0]-2*X[1]])

X_f0=np.array([0.0   , 0.0   ])
print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')
all(dX_dt(X_f0) == np.zeros(2) )
# Out:
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0.]
# True

# %%
t = np.linspace(1, 8,  500)              # Rango de tiempo de integración
X0 = np.array([0, 3])                     # Condiciones iniciales
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
x, y = X.T
plt.plot(x, y, 'brown')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.ylim(0, 10)
plt.xlim(0, 10)
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# **Ejercicio 9:**
#
# \begin{eqnarray*}
# \frac{d x}{d t} & = & A x  \\
# x(0) & = & (0,-b,b) \\
# A & = & \begin{bmatrix}
# 2 & 0 & 0 \\
# 0 & -1 & 0 \\
# 0 & 2 & -3 \\
# \end{bmatrix}
# \end{eqnarray*}

# %%
# A = 2 0 0
#     0 -1 0
#     0 2 -3 

A = np.array([[2,0,0],[0,-1,0],[0,2,-3]])
print('A=',A)
p=np.trace(A)
q=la.det(A)
d=p**2-4*q
print("det(A)/q =",q)
print("Traza(A)/p =",p)
print("Delta =",d)
eigvals, eigvecs = la.eig(A)
print("eigvals =",eigvals)
print("eigvecs =",eigvecs)
# Out:
# A= [[ 2  0  0]
#  [ 0 -1  0]
#  [ 0  2 -3]]
# det(A)/q = 6.0
# Traza(A)/p = -2
# Delta = -20.0
# eigvals = [ 2.+0.j -3.+0.j -1.+0.j]
# eigvecs = [[1.         0.         0.        ]
#  [0.         0.         0.70710678]
#  [0.         1.         0.70710678]]

# %%
def dX_dt(X,t=0):
  return np.array([2*X[0],
                   -1*X[1],
                   2*X[1]-3*X[2]])
X_f0=np.array([0.0  ,  0.0 ,   0.0 ])
#Puntos criticos del sistema

print('Puntos criticos del sistema son ')
print(X_f0)
print()

#En los puntos criticos se anulan las derivadas
all(dX_dt(X_f0)==np.zeros(3))

#Ya tenemos los eigenvalores y vectores

t=np.linspace(0,25,1000)
fig = plt.figure()
ax = plt.axes(projection ='3d')


for b in [1,2,3,4,5]:
  X0=np.array([0,-1*b,b])
  X, infodict = integrate.odeint(dX_dt,X0,t,full_output=True)
  infodict['message']
  x ,y ,z = X.T
  ax.plot3D(x, y, z,)
  #legend='Para b igual a ',b
  #plt.legend(legend)


label='Familias de soluciónes en el espacio fase (x(t),y(t),z(t))'
ax.set_title(label)
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.xlabel('x');
plt.ylabel('y');
plt.show()
# Out:
# Puntos criticos del sistema son
# [0. 0. 0.]

# %% [markdown]
# ### Equilibrio de Sistemas No Lineales
#
# Estudiaremos sistemas de ecuaciones diferenciales no lineales cuyos puntos críticos son el origen.
#
# Veremos que las soluciones de los sistemas no lineales cerca del origen se comportan como las soluciones de sistemas linealizados alrededor del origen.
#
# Analicemos el siguiente sistema de ecuaciones diferenciales no lineales
#
# \begin{eqnarray}
# \frac{dx}{dt} & = & f(x,y) \\
# \frac{dy}{dt} & = & g(x,y) \\
# \end{eqnarray}
#
# Supongamos que el punto crítico es ($x,y$)=($\bar{x},\bar{y}$), donde se anula el lado derecho del sistema de ecuaciones, es decir $f(\bar{x}, \bar{y}) = 0$ y $g(\bar{x}, \bar{y}) = 0$.
#
# Nos interesa saber si el punto crítico es estable o inestable.
#
# Consideremos una pequeña perturbación alrededor del punto crítico
#
# \begin{eqnarray*}
# x & = & \bar{x} + u  \\
# y & = & \bar{y} + v  \\
# \end{eqnarray*}
#
# donde $u$ y $v$ son pequeñas. La pregunta de estabilidad del punto crítico se replantea de si $u$ y $v$ crecerán infinitamente o no.
#
# Podemos escribir el sistema de ecuaciones que satisfacen $u$ y $v$
#
# \begin{eqnarray*}
# \frac{du}{dt} & = & \frac{dx}{dt} \\
#               & = & f(x,y) \\
#               & = & f(\bar{x} + u, \bar{y} + v) \\
#               & = & f(\bar{x}, \bar{y}) +
#               \frac{\partial f}{\partial x}(\bar{x}, \bar{y}) \ u + \frac{\partial f}{\partial y}(\bar{x}, \bar{y}) \ v + \cdots \\
#               & = & \frac{\partial f}{\partial x}(\bar{x}, \bar{y}) \ u + \frac{\partial f}{\partial y}(\bar{x}, \bar{y}) \ v + \cdots \\
# \end{eqnarray*}
#
# De forma similar obtenemos la ecuación para $v$
# \begin{eqnarray*}
# \frac{dv}{dt} & = & \frac{\partial g}{\partial x}(\bar{x}, \bar{y}) \ u + \frac{\partial g}{\partial y}(\bar{x}, \bar{y}) \ v + \cdots \\
# \end{eqnarray*}
#
# Podemos suponer que los terminos $u^2, v^2, uv, \ldots$, son muy pequeños, por lo que podemos aproximar el sistema de ecuaciones por
#
# \begin{equation*}
# \frac{d}{dt}\begin{bmatrix}
# u \\
# v \\
# \end{bmatrix} = \begin{bmatrix}
# \frac{\partial f}{\partial x}(\bar{x}, \bar{y}) & \frac{\partial f}{\partial y}(\bar{x}, \bar{y}) \\
# \frac{\partial g}{\partial x}(\bar{x}, \bar{y})  & \frac{\partial g}{\partial y}(\bar{x}, \bar{y}) \\
# \end{bmatrix}
# \begin{bmatrix}
# u \\
# v \\
# \end{bmatrix} = {\bf J} \begin{bmatrix}
# u \\
# v \\
# \end{bmatrix}
# \end{equation*}
#
# La matriz ${\bf J}$ es la matriz Jacobiana, evaluada el el punto crítico $(\bar{x}, \bar{y})$.
#
# El sistema anterior tiene el punto crítico $(\bar{x}, \bar{y}) = (0,0)$, y los eigenvalores de la matriz ${\bf J}$ determinan la naturaleza de los puntos críticos, como los que se vió en este tema.
#
# En este caso podemos afirmar en sólo dos casos:
#
# *  Si la parte real de los eigenvalores son positivos, el punto crítico es inestable.
# *  El caso contrario, si la parte real de los eigenvalores son negativos, entonces el punto crítico es estable.
#
# Cualquier otro resultado (por ej. parte real cero), no podremos decir mucho, sino que requeriremos incluir más términos de orden superior, ya que estaremos en una frontera no bien determinada.
#
# Un resultado del [Teorema de Hartman-Grobman](https://en.wikipedia.org/wiki/Hartman–Grobman_theorem) garantiza que la estabilidad del punto crítico del sistema original $(\bar{x}, \bar{y})$ es la misma que el punto crítico $(0,0)$ del sistema linearizado.

# %% [markdown]
# **Ejemplo: Sistema de Lotka Volterra**
#
# El sistema de ecuaciones de [Lotka-Volterra](https://en.wikipedia.org/wiki/Lotka–Volterra_equations), describe la dinámica poblacional de dos especies: presa-depredador, por ejemplo conejos y zorros.
#
# El sistema de ecuaciones que describe la variación de la población, está dado por
#
# \begin{eqnarray*}
# \frac{dx}{dt} & = &  a x - b x y \\
# \frac{dy}{dt} & = &  -c y + d x y  \\
# \end{eqnarray*}
#
# donde $x$ es el número de presas (p. ej. conejos)
# y $y$ el número de depredadores (p. ej. zorros).
#
# Los parámetros $b, d$ corresponden a las interacciones entre las especies, $a$ es la taza de natalidad de los conejos y $c$ la taza de extinción de los zorros si no hay alimento.

# %%
# Ejemplo de Lotka-Volterra

import numpy as np
from scipy import integrate, linalg
import pylab as plt

# Definimos un vector X: X[0]=x, X[1]=y

# Definimos los parámetros 
a = 1.
b = 0.1
c = 1.5
d = 0.75

def dX_dt(X, t=0):
    """ El lado derecho del sistema de ecuaciones """
    return np.array([ a*X[0] -   b*X[0]*X[1] ,
                  -c*X[1] + d*b*X[0]*X[1] ])

# %%
# Los puntos críticos del sistema
X_f0 = np.array([     0. ,  0.])
X_f1 = np.array([ c/(d*b), a/b])

print('Puntos críticos del sistema para estos valores de parámetros')
print('X_f0:', X_f0)
print('X_f1:', X_f1)

# En los puntos críticos se anulan las derivadas. 
all(dX_dt(X_f0) == np.zeros(2) ) and all(dX_dt(X_f1) == np.zeros(2))

def d2X_dt2(X, t=0):
    """ El Jacobiano evaluado en X}. """
    return np.array([[a -b*X[1],   -b*X[0]     ],
                  [b*d*X[1] ,   -c +b*d*X[0]] ])
# Out:
# Puntos críticos del sistema para estos valores de parámetros
# X_f0: [0. 0.]
# X_f1: [20. 10.]

# %%
# El Jacobiano evaluado en el primer punto crítico X_f0
A_f0 = d2X_dt2(X_f0)
print('A_f0:')
print(A_f0)
# Out:
# A_f0:
# [[ 1.  -0. ]
#  [ 0.  -1.5]]

# %%
# El Jacobiano evaluado en el segundo punto crítico X_f1
A_f1 = d2X_dt2(X_f1)                    
print('A_f1:')
print(A_f1)
                                
# Y sus eigenvalores son +/- sqrt(c*a).j:
lambda1, lambda2 = linalg.eigvals(A_f1) 
print('Eigenvalores:', lambda1, lambda2)
# >>> (1.22474j, -1.22474j)

# Los eigenvalores son imaginarios
# Con periodo
T_f1 = 2*np.pi/abs(lambda1) 
print('Periodo:', T_f1)
# Out:
# A_f1:
# [[ 0.   -2.  ]
#  [ 0.75  0.  ]]
# Eigenvalores: 1.224744871391589j -1.224744871391589j
# Periodo: 5.130199320647456

# %%
# Integramos el sistema de ecuaciones de Lotka-Volterra usando odeint

t = np.linspace(0, 15,  1000)              # Rango de tiempo de integración
X0 = np.array([10, 5])                     # Condiciones iniciales: 10 conejos y 5 zorros
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
# Out:
# 'Integration successful.'

# %%
# Graficamos las soluciones

conejos, zorros = X.T


f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, conejos, 'r-', label='Conejos');
plt.plot(t, zorros  , 'b-', label='Zorros');
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('población');
plt.title('Evolución de la población de conejos y zorros');
plt.show();

# %%
# Graficamos la familia de soluciones en el espacio fase para distintas condiciones iniciales

values  = np.linspace(0.3, 0.9, 5)                         # posición de X0 entre X_f0 y X_f1
vcolors = plt.cm.cividis(np.linspace(0.3, 1., len(values)))  # colores para cada trayectoria

plt.figure(figsize=(12, 8)); 

#-------------------------------------------------------
# grafica las trayectorias
for v, col in zip(values, vcolors):
    X0 = v * X_f1                               # punto inicial
    X = integrate.odeint( dX_dt, X0, t)         # Integración para cada condición inicial
    plt.plot( X[:,0], X[:,1], lw=3.5*v, color=col, label='X0=(%.f, %.f)' % ( X0[0], X0[1]) )

#-------------------------------------------------------
# define una malla y calcula la pendiente (dirección) en cada punto
ymax = plt.ylim(ymin=0)[1]                        # get axis limits
xmax = plt.xlim(xmin=0)[1]
nb_points   = 20

x = np.linspace(0, xmax, nb_points)
y = np.linspace(0, ymax, nb_points)

X1 , Y1  = np.meshgrid(x, y)                       # crea la malla
DX1, DY1 = dX_dt([X1, Y1])                      # calcula la tasa de crecimiento
M = (np.hypot(DX1, DY1))                           # distancia euclideana 
M[ M == 0] = 1.                                 # Evita divisiones entre 0 
DX1 /= M                                        # Normaliza el tamaño de cada flecha
DY1 /= M

#-------------------------------------------------------
# Dibujar los campos de direcciones usando la función quiver de Matplotlib 
# EL color de las flechas indica la rapidez de crecimiento

plt.title('Plano Fase: Trayectorias y campo de direcciones - Punto crítico (20,10)')
Q = plt.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=p.cm.jet)
plt.xlabel('Número de conejos')
plt.ylabel('Número de zorros')
plt.legend(loc='best')
plt.grid()
plt.xlim(0, xmax)
plt.ylim(0, ymax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-5bba50ae385a> in <module>()
#      34
#      35 plt.title('Plano Fase: Trayectorias y campo de direcciones - Punto crítico (20,10)')
# ---> 36 Q = plt.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=p.cm.jet)
#      37 plt.xlabel('Número de conejos')
#      38 plt.ylabel('Número de zorros')
#
# AttributeError: 'numpy.int64' object has no attribute 'cm'

# %% [markdown]
# **Ejercicio 10:**
#
# Se tiene el siguiente sistema de resortes acoplados con dos masas.
#
# ![Screen Shot 2021-03-18 at 00.35.32.png](data:image/png;base64,...)

# %% [markdown]
# El sistema esta sujeto del primer resorte de la izquierda. Cuando el sistema se deja en reposo, las longitudes de los resortes son $L_1$ y $L_2$.
#
# Las ecuaciones de movimiento estan dadas por las siguientes ecuaciones diferenciales acopladas:
#
# \begin{eqnarray*}
# m_1 x_1^{''} + b_1 x_1^{'}+k_1 (x_1-L_1)-k_2(x_2-x_1-L_2) & = & 0 \\
# m_2 x_2^{''} + b_2 x_2^{'}+k_2(x_2-x_1-L_2) & = & 0 \\
# \end{eqnarray*}
#
# Encuentre las soluciones como funciones de $t$ y grafíquelas, así como las trayectorias en el espacio fase.
#
# Suponga que $L_1=L_2=1$ y que las masas son iguales $m_1=m_2=1$.
#
# **10.1)** Encuentre los eigenvalores del sistema y diga como son las soluciones.
#
# **10.2)** Caso sin fricción. $b_1=b_2=0$, $k_1=6$, $k_2=4$, condiciones iniciales $(x_1(0), x_1^{'}(0), x_2(0), x_2^{'}(0))=(1,0,4,0)$
#
# **10.3)** Igual que el caso anterior pero, con fricción: $b_1=0.1, b_2=0.2$

# %%
import numpy as np
from scipy import integrate, linalg
import pylab as plt

# Definimos un vector X: X[0]=x1, X[1]=x2, X[2]=x3, X[3]=x4
# Definimos la Matriz A 

A10 = np.array([[0,0,1,0], [0,0,0,1], [-6-4,4,0,0], [4,-4,0,0]])
print('A =', A10)

def dX_dt_10(X,t=0):
    """ El lado derecho del sistema de ecuaciones """
    return np.array([0*X[0] + 0*X[1] + 1*X[2] + 0*X[3], 0*X[0] + 0*X[1] + 0*X[2] + 1*X[3], -10*X[0] + 4*X[1] + 0*X[2] + 0*X[3], 4*X[0] - 4*X[1] + 0*X[2] + 0*X[3]])
    
# Los puntos críticos del sistema
X_f0 = np.array([ 0.0 , 0.0, 0.0, 0.0])

print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')
# En los puntos críticos se anulan las derivadas. 
all(dX_dt_10(X_f0) == np.zeros(4) )
                                
# Aplicamos la biblioteca scipy.linalg.eig()
eigvals10, eigvecs10 = linalg.eig(A10)
print('Eigenvalores:', eigvals10)
print('Eigenvectores:', eigvecs10)
# Out:
# A = [[  0   0   1   0]
#  [  0   0   0   1]
#  [-10   4   0   0]
#  [  4  -4   0   0]]
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0. 0. 0.]
#
# Eigenvalores: [-7.84812828e-18+3.46410162j -7.84812828e-18-3.46410162j
#   3.56037039e-17+1.41421356j  3.56037039e-17-1.41421356j]
# Eigenvectores: [[ 5.40083802e-18-2.48069469e-01j  5.40083802e-18+2.48069469e-01j
#   -3.71147146e-17-2.58198890e-01j -3.71147146e-17+2.58198890e-01j]
#  [ 6.88127078e-18+1.24034735e-01j  6.88127078e-18-1.24034735e-01j
#   -4.78087849e-17-5.16397779e-01j -4.78087849e-17+5.16397779e-01j]
#  [ 8.59337849e-01+0.00000000e+00j  8.59337849e-01-0.00000000e+00j
#    3.65148372e-01+2.43165361e-17j  3.65148372e-01-2.43165361e-17j]
#  [-4.29668924e-01+2.20804798e-18j -4.29668924e-01-2.20804798e-18j
#    7.30296743e-01+0.00000000e+00j  7.30296743e-01-0.00000000e+00j]]

# %%
# Solución
# Los eigenvectores son linealmente independientes
lambda1_10 = eigvals10[0]
lambda2_10 = eigvals10[1]
lambda3_10 = eigvals10[2]
lambda4_10 = eigvals10[3]
print('Eigenvalores')
print('lambda1= ', lambda1_10)
print('lambda2= ', lambda2_10)
print('lambda3= ', lambda3_10)
print('lambda4= ', lambda4_10)
print(' ')
print('Eigenvectores')
v1_10 = eigvecs10[:,0]
v2_10 = eigvecs10[:,1]
v3_10 = eigvecs10[:,2]
v4_10 = eigvecs10[:,3]
print('v1=',v1_10)
print('v2=',v2_10)
print('v3=',v3_10)
print('v4=',v4_10)
# Out:
# Eigenvalores
# lambda1=  (-7.848128277522717e-18+3.4641016151377553j)
# lambda2=  (-7.848128277522717e-18-3.4641016151377553j)
# lambda3=  (3.5603703886533236e-17+1.4142135623730951j)
# lambda4=  (3.5603703886533236e-17-1.4142135623730951j)
#
# Eigenvectores
# v1= [ 5.40083802e-18-2.48069469e-01j  6.88127078e-18+1.24034735e-01j
#   8.59337849e-01+0.00000000e+00j -4.29668924e-01+2.20804798e-18j]
# v2= [ 5.40083802e-18+2.48069469e-01j  6.88127078e-18-1.24034735e-01j
#   8.59337849e-01-0.00000000e+00j -4.29668924e-01-2.20804798e-18j]
# v3= [-3.71147146e-17-2.58198890e-01j -4.78087849e-17-5.16397779e-01j
#   3.65148372e-01+2.43165361e-17j  7.30296743e-01+0.00000000e+00j]
# v4= [-3.71147146e-17+2.58198890e-01j -4.78087849e-17+5.16397779e-01j
#   3.65148372e-01-2.43165361e-17j  7.30296743e-01-0.00000000e+00j]

# %%
# Solución numérica
# Integramos el sistema de ecuaciones de Lotka-Volterra usando odeint

t = np.linspace(0, 50,  500)              # Rango de tiempo de integración
X0_10 = np.array([1,4,0,0])                     # Condiciones iniciales
X, infodict = integrate.odeint(dX_dt_10, X0_10, t, full_output=True)
infodict['message'] 

# Solución en el plano fase
x1, x3, x2, x4= X.T

plt.figure(figsize=(15,7))
plt.plot(t, x1, label = 'x1')
plt.plot(t, x2, label = 'x2')
plt.legend(loc='best');
plt.xlabel('t')
plt.ylabel('y')
plt.grid()
plt.title('Soluciones como funciones de t')
plt.show()

# %%
# Solución numérica
# Integramos el sistema de ecuaciones de Lotka-Volterra usando odeint

t = np.linspace(0, 50,  500)              # Rango de tiempo de integración
X0_10 = np.array([1,4,0,0])                     # Condiciones iniciales
X, infodict = integrate.odeint(dX_dt_10, X0_10, t, full_output=True)
infodict['message'] 

# Solución en el plano fase
x1, x2, x3, x4 = X.T

plt.figure(figsize=(10,10))
plt.plot(x1, x2)
plt.xlabel('x1')
plt.ylabel('x2')
plt.grid()
plt.title('Solución en el plano fase')
plt.show()

# %%
# Ahora con fricción

# Definimos un vector X: X[0]=x1, X[1]=x2, X[2]=x3, X[3]=x4
# Definimos la Matriz A 

A11 = np.array([[0,0,1,0], [0,0,0,1], [-6-4,4,-.1,0], [4,-4,0,.2]])
print('A =', A11)

def dX_dt_11(X,t=0):
    """ El lado derecho del sistema de ecuaciones """
    return np.array([0*X[0] + 0*X[1] + 1*X[2] + 0*X[3], 0*X[0] + 0*X[1] + 0*X[2] + 1*X[3], -10*X[0] + 4*X[1] - .1*X[2] + 0*X[3], 4*X[0] - 4*X[1] + 0*X[2] + .2*X[3]])
    
# Los puntos críticos del sistema
X_f0 = np.array([ 0.0 , 0.0, 0.0, 0.0])

print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')
# En los puntos críticos se anulan las derivadas. 
all(dX_dt_11(X_f0) == np.zeros(4) )
                                
# Aplicamos la biblioteca scipy.linalg.eig()
eigvals11, eigvecs11 = linalg.eig(A11)
print('Eigenvalores:', eigvals11)
print('Eigenvectores:', eigvecs11)
# Out:
# A = [[  0.    0.    1.    0. ]
#  [  0.    0.    0.    1. ]
#  [-10.    4.   -0.1   0. ]
#  [  4.   -4.    0.    0.2]]
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0. 0. 0.]
#
# Eigenvalores: [-0.02012662+3.46155525j -0.02012662-3.46155525j  0.07012662+1.41349145j
#   0.07012662-1.41349145j]
# Eigenvectores: [[-0.00144405-0.24836076j -0.00144405+0.24836076j  0.00185975-0.25752332j
#    0.00185975+0.25752332j]
#  [ 0.01355753+0.12311055j  0.01355753-0.12311055j  0.02558946-0.51578829j
#    0.02558946+0.51578829j]
#  [ 0.85974355+0.j          0.85974355-0.j          0.36413743-0.0154305j
#    0.36413743+0.0154305j ]
#  [-0.42642685+0.04445234j -0.42642685-0.04445234j  0.73085685+0.j
#    0.73085685-0.j        ]]

# %%
# Solución
# Los eigenvectores son linealmente independientes
lambda1_11 = eigvals11[0]
lambda2_11 = eigvals11[1]
lambda3_11 = eigvals11[2]
lambda4_11 = eigvals11[3]
print('Eigenvalores')
print('lambda1= ', lambda1_11)
print('lambda2= ', lambda2_11)
print('lambda3= ', lambda3_11)
print('lambda4= ', lambda4_11)
print(' ')
print('Eigenvectores')
v1_11 = eigvecs11[:,0]
v2_11 = eigvecs11[:,1]
v3_11 = eigvecs11[:,2]
v4_11 = eigvecs11[:,3]
print('v1=',v1_11)
print('v2=',v2_11)
print('v3=',v3_11)
print('v4=',v4_11)
# Out:
# Eigenvalores
# lambda1=  (-0.020126617484558462+3.4615552487106176j)
# lambda2=  (-0.020126617484558462-3.4615552487106176j)
# lambda3=  (0.07012661748455859+1.4134914514545762j)
# lambda4=  (0.07012661748455859-1.4134914514545762j)
#
# Eigenvectores
# v1= [-0.00144405-0.24836076j  0.01355753+0.12311055j  0.85974355+0.j
#  -0.42642685+0.04445234j]
# v2= [-0.00144405+0.24836076j  0.01355753-0.12311055j  0.85974355-0.j
#  -0.42642685-0.04445234j]
# v3= [0.00185975-0.25752332j 0.02558946-0.51578829j 0.36413743-0.0154305j
#  0.73085685+0.j        ]
# v4= [0.00185975+0.25752332j 0.02558946+0.51578829j 0.36413743+0.0154305j
#  0.73085685-0.j        ]

# %%
# Solución numérica
# Integramos el sistema de ecuaciones de Lotka-Volterra usando odeint

t = np.linspace(0, 50, 500)              # Rango de tiempo de integración
X0_11 = np.array([1,4,0,0])                     # Condiciones iniciales
X, infodict = integrate.odeint(dX_dt_11, X0_11, t, full_output=True)
infodict['message'] 

# Solución en el plano fase
x1, x3, x2, x4= X.T

plt.figure(figsize=(15,7))
plt.plot(t, x1, label = 'x1')
plt.plot(t, x2, label = 'x2')
plt.legend(loc='best');
plt.xlabel('t')
plt.ylabel('y')
plt.grid()
plt.title('Soluciones como funciones de t')
plt.show()

# %%
# Solución numérica
# Integramos el sistema de ecuaciones de Lotka-Volterra usando odeint

t = np.linspace(0, 20,  500)              # Rango de tiempo de integración
X0_11 = np.array([1,4,0,0])                     # Condiciones iniciales
X, infodict = integrate.odeint(dX_dt_11, X0_11, t, full_output=True)
infodict['message'] 

# Solución en el plano fase
x1, x2, x3, x4 = X.T

plt.figure(figsize=(10,10))
plt.plot(x1, x2)
plt.xlabel('x1')
plt.ylabel('x2')
plt.grid()
plt.title('Solución en el plano fase')
plt.show()

# %% [markdown]
# Solución Ejemplo 7:
#
# \begin{eqnarray*}
# \frac{dx}{dt} & = & 2x+y \\
# \frac{dy}{dt} & = & x+y \\
# \end{eqnarray*}
#
# Con condiciones iniciales: $x(1)=1$ y $y(1)=1$.
#
# Equivale al problema
#
# \begin{equation*}
# \frac{d}{dt}\begin{bmatrix} x \\ y \end{bmatrix} = A \begin{bmatrix} x \\ y \end{bmatrix}
# \end{equation*}
#
# Donde la matriz $A$ está definida por
#
# \begin{bmatrix}
# 2 & 1 \\
# 1 & 1 \\
# \end{bmatrix}
#
# Definimos $X = [x,y]^T$.
#
# La solución de este sistema es
#
# \begin{equation*}
# X(t) = X(1) \exp(At) = X(1) P \exp(\Lambda t) P^{-1}
# \end{equation*}
#
# Donde $P$ es la matriz de eigenvectores y $\Lambda$ la matriz de los eigenvalores $\lambda_1$ y $\lambda_2$ de la matriz de transformación $A$ (det$A \neq 0$)

# %%
# Resolviendo Ejercicio 7

import numpy as np
from scipy import integrate, linalg
import pylab as plt

# Definimos un vector X: X[0]=x, X[1]=y
# Definimos la Matriz A 

A7 = np.array([[2,1], [1,1]])
print('A =', A7)

def dX_dt(X, t=1):
    """ El lado derecho del sistema de ecuaciones """
    return np.array([ 2*X[0] + X[1] ,
                  X[0]+X[1]])
    
# Los puntos críticos del sistema
X_f0 = np.array([     0. ,  0.])

print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')
# En los puntos críticos se anulan las derivadas. 
all(dX_dt(X_f0) == np.zeros(2) )
                                
# Aplicamos la biblioteca scipy.linalg.eig()
eigvals, eigvecs = linalg.eig(A7)
print('Eigenvalores:', eigvals)
print('Eigenvectores:', eigvecs)
# Out:
# A = [[2 1]
#  [1 1]]
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0.]
#
# Eigenvalores: [2.61803399+0.j 0.38196601+0.j]
# Eigenvectores: [[ 0.85065081 -0.52573111]
#  [ 0.52573111  0.85065081]]

# %%
# Solución
# Los eigenvectores son linealmente independientes
lambda1 = eigvals[0]
lambda2 = eigvals[1]
print('Eigenvalores')
print('lambda1= ', lambda1)
print('lambda2= ', lambda2)
print(' ')
print('Eigenvectores')
v1 = eigvecs[:,0]
v2 = eigvecs[:,1]
print('v1=',v1)
print('v2=',v2)
# Out:
# Eigenvalores
# lambda1=  (2.618033988749895+0j)
# lambda2=  (0.3819660112501052+0j)
#
# Eigenvectores
# v1= [0.85065081 0.52573111]
# v2= [-0.52573111  0.85065081]

# %%
# Solución numérica
# Integramos el sistema de ecuaciones de Lotka-Volterra usando odeint

t = np.linspace(1, 5,  500)              # Rango de tiempo de integración
X0 = np.array([1, 1])                     # Condiciones iniciales
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
# Out:
# 'Integration successful.'

# %%
x, y = X.T

f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)');
plt.plot(t, y  , 'b-', label='y(t)');
plt.grid();
plt.ylim(0, 10)
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t)');
plt.show();

# %%
# Solución en el plano fase

plt.plot(x, y, 'brown')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.ylim(0, 10)
plt.xlim(0, 10)
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# Buscamos la solución general
#
# \begin{equation*}
# X(t) = c_1 \exp(\lambda_1 t) \vec{v_1} +
# c_2 \exp(\lambda_2 t) \vec{v_2}
# \end{equation*}
#
# **NOTA:** Haré la suposición de que $c_1$ y $c_2$, tienen componentes ($c_{11},c_{12}, c_{21}, c_{22}$). Veremos que no era necesario, pues $c_{11}=c_{21}$ y $c_{12}=c_{22}$.

# %%
# Solución del sistema
t = np.linspace(1, 5,  500)              # Rango de tiempo de integración

# Tenemos 4 ecuaciones y 4 constantes c11,c12,c21,c22
# Xsol=c11*np.exp(lambda1*t)*v1[0]+c12*np.exp(lambda2*t)*v2[0]
# Ysol=c21*np.exp(lambda1*t)*v1[1]+c22*np.exp(lambda2*t)*v2[1]
# Xsol'= 2*Xsol + Ysol 
#      = lambda1*c11*np.exp(lambda1*t)*v1[0]+lambda2*c12*np.exp(lambda2*t)*v2[0]
# Ysol'= Xsol + Ysol
#      = lambda1*c21*np.exp(lambda1*t)*v1[1]+lambda2*c22*np.exp(lambda2*t)*v2[1]
       
# Aplicamos las condiciones iniciales
# Xsol(1) = c11*b11 + c12*b12 = 1
# Ysol(1) = c21*b21 + c22*b22 = 1
# Xsol'(1) = 2*Xsol(1) + Ysol(1) = 3 
#          = lambda1*c11*np.exp(lambda1)*v1[0]+lambda2*c12*np.exp(lambda2)*v2[0]
#          = lambda1*c11*b11+lambda2*c12*b12
# Ysol'(1) = Xsol(1) + Ysol(1) = 2
#          = lambda1*c21*b21+lambda2*c22*b22



b11 = np.exp(lambda1)*v1[0]
b12 = np.exp(lambda2)*v2[0]
b21 = np.exp(lambda1)*v1[1]
b22 = np.exp(lambda2)*v2[1]

# %%
# Buscamos los valores de c1 y c2 que satisfacen las condiciones iniciales
# B1 [c11,c12]^T = [1,3]^T
# [c11,c12]^T = B1^{-1} [1,3^T]
# B2 [c21,c22]^T = [1,2]^T
# [c21,c22]^T = B2^{-1}[1,2]^T
B1 = np.array([[b11,b12], [lambda1*b11,lambda2*b12]])
B2 = np.array([[b21,b22] ,[lambda1*b21,lambda2*b22]])
print('B1=', B1)
print(' ')
print('B2=', B2)
print(' ')
B1_inv = linalg.inv(B1)
B2_inv = linalg.inv(B2)

print('B1_inv = [[B1_inv[0][0], B1_inv[0][1]],')
print('         [B1_inv[1][0], B1_inv[1][1]]]')
print('B1_inv=', B1_inv)
print(' ')
print('B2_inv = [[B2_inv[0][0], B2_inv[0][1]],')
print('         [B2_inv[1][0], B2_inv[1][1]]]')
print('B2_inv=', B2_inv)
print(' ')


c_11 = B1_inv[0][0] + 3*B_inv[0][1] 
c_12 = B1_inv[1][0] + 3*B_inv[1][1] 
c_21 = B2_inv[0][0] + 2*B2_inv[0][1] 
c_22 = B2_inv[1][0] + 2*B2_inv[1][1] 
print(' ')
print('c11=', c_11)
print('c12=', c_12)
print('c21=', c_21)
print('c22=', c_22)


# Satisface las condiciones iniciales?
x1=c_11*np.exp(lambda1)*v1[0]+c_12*np.exp(lambda2)*v2[0]
x2=c_21*np.exp(lambda1)*v1[1]+c_22*np.exp(lambda2)*v2[1]
print('Condiciones iniciales: x(1), y(1):', x1, x2)
# Out:
# B1= [[11.66135546+0.j -0.7702814 +0.j]
#  [30.52982496+0.j -0.29422131+0.j]]
#
# B2= [[ 7.20711403+0.j  1.24634148+0.j]
#  [18.86846949+0.j  0.47606008+0.j]]
#
# B1_inv = [[B1_inv[0][0], B1_inv[0][1]],
#          [B1_inv[1][0], B1_inv[1][1]]]
# B1_inv= [[-0.01464842+0.j  0.03835005+0.j]
#  [-1.51999048-0.j  0.5805847 +0.j]]
#
# B2_inv = [[B2_inv[0][0], B2_inv[0][1]],
#          [B2_inv[1][0], B2_inv[1][1]]]
# B2_inv= [[-0.02370164-0.j  0.06205169+0.j]
#  [ 0.93940578-0.j -0.35882108+0.j]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-d41544b3c91c> in <module>()
#      23
#      24
# ---> 25 c_11 = B1_inv[0][0] + 3*B_inv[0][1]
#      26 c_12 = B1_inv[1][0] + 3*B_inv[1][1]
#      27 c_21 = B2_inv[0][0] + 2*B2_inv[0][1]
#
# NameError: name 'B_inv' is not defined

# %%
x, y = Xsol, Ysol

f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)');
plt.plot(t, y  , 'b-', label='y(t)');
plt.grid();
plt.ylim(0, 10)
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t)');
plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-eee7e76c9fba> in <module>()
#       1
# ----> 2 x, y = Xsol, Ysol
#       3
#       4 f1 = plt.figure();
#       5 plt.figure(figsize=(10, 5));
#
# NameError: name 'Xsol' is not defined

# %% [markdown]
# **Ejemplo de Solución de un sistema 3x3**
#
# Resolveremos el sistema
#
# \begin{eqnarray*}
# x_1' & = & x_1 \\
# x_2' & = & x_1 + 2 x_2 \\
# x_3' & = & x_1 - x_3 \\
# \end{eqnarray*}
#
# con condiciones iniciales $\vec{X}(0)=(1,0,0)$.
#
# O si lo escribimos de forma matricial
#
# \begin{equation*}
# \vec{X'} = \begin{bmatrix} 1 & 0 & 0 \\
# 1 & 2 & 0 \\
# 1 &  0 & -1\\ \end{bmatrix} \vec{X} =
# A \vec{X}
# \end{equation*}
#
# Buscaremos los eigenvalores y eigenvectores de la matriz $A$
#
# \begin{equation*}
# A = P \Lambda P^{-1}
# \end{equation*}
#
# donde $P$ es la matriz de los eigenvectores y $\Lambda$ la matriz diagonal de los eigenvalores.

# %%
import numpy as np
from scipy import integrate, linalg
import pylab as plt

# Definimos un vector X: X[0]=x, X[1]=y, X[2]=z
# Definimos la Matriz A 

A3 = np.array([[1,0,0],[1,2,0], [1,0,-1]])
print('A =', A3)

def dX_dt(X,t=0):
    """ El lado derecho del sistema de ecuaciones """
    return np.array([X[0], X[0] + 2*X[1] ,
                  X[0]-X[1]])
    
# Los puntos críticos del sistema
X_f0 = np.array([ 0.0 , 0.0, 0.0])

print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')
# En los puntos críticos se anulan las derivadas. 
all(dX_dt(X_f0) == np.zeros(3) )
                                
# Aplicamos la biblioteca scipy.linalg.eig()
eigvals, eigvecs = linalg.eig(A3)
print('Eigenvalores:', eigvals)
print('Eigenvectores:', eigvecs)
# Out:
# A = [[ 1  0  0]
#  [ 1  2  0]
#  [ 1  0 -1]]
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0. 0.]
#
# Eigenvalores: [-1.+0.j  2.+0.j  1.+0.j]
# Eigenvectores: [[ 0.          0.          0.66666667]
#  [ 0.          1.         -0.66666667]
#  [ 1.          0.          0.33333333]]

# %%
# Solución
# Los eigenvectores son linealmente independientes
lambda1 = eigvals[0]
lambda2 = eigvals[1]
lambda3 = eigvals[2]
print('Eigenvalores')
print('lambda1= ', lambda1)
print('lambda2= ', lambda2)
print('lambda3= ', lambda3)
print(' ')
print('Eigenvectores')
v1 = eigvecs[:,0]
v2 = eigvecs[:,1]
v3 = eigvecs[:,2]
print('v1=',v1)
print('v2=',v2)
print('v3=',v3)
# Out:
# Eigenvalores
# lambda1=  (-1+0j)
# lambda2=  (2+0j)
# lambda3=  (1+0j)
#
# Eigenvectores
# v1= [0. 0. 1.]
# v2= [0. 1. 0.]
# v3= [ 0.66666667 -0.66666667  0.33333333]

# %%
# La solución del sistema 
# Solución numérica
# Integramos el sistema de ecuaciones de Lotka-Volterra usando odeint

t = np.linspace(0, 3,  300)              # Rango de tiempo de integración
X0 = np.array([1, 0, 0])                     # Condiciones iniciales
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
# Out:
# 'Integration successful.'

# %%
x, y, z = X.T

f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)');
plt.plot(t, y  , 'b-', label='y(t)');
plt.plot(t, z  , 'g-', label='z(t)');
plt.grid();
plt.ylim(-10, 10)
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t), z(t)');
plt.show();

# %%
# Solución en el plano fase

plt.plot(x, y, 'brown')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.ylim(-10, 10)
plt.xlim(-10, 10)
plt.title('Solución X(t) en el plano fase xy')
plt.show()

# %%
plt.plot(x, z, 'brown')
plt.xlabel('x')
plt.ylabel('z')
plt.grid()
plt.ylim(-10, 10)
plt.xlim(-10, 10)
plt.title('Solución X(t) en el plano fase xz')
plt.show()

# %%
plt.plot(y, z, 'brown')
plt.xlabel('y')
plt.ylabel('z')
plt.grid()
plt.ylim(-10, 10)
plt.xlim(-10, 10)
plt.title('Solución X(t) en el plano fase yz')
plt.show()

# %%
# Solución en el plano fase
 
# importing mplot3d toolkits, numpy and matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
  
fig = plt.figure()
  
# syntax for 3-D projection
ax = plt.axes(projection ='3d')


plt.xlim(-10, 10)
plt.ylim(-10, 10)

plt.xlabel('x');
plt.ylabel('y');

# defining all 3 axes
x, y, z = X.T
  
# plotting
ax.plot3D(x, y, z, 'brown')
ax.set_title('Solución en el espacio fase (x(t),y(t),z(t))')
plt.show()

# %% [markdown]
# La solución analítica de esta ecuación con 3 eigenvalores reales distintos es:
#
# \begin{equation*}
# \vec{X}(t) = c_1 \exp(\lambda_1 t) \vec{v_1}
# + c_2 \exp(\lambda_2 t) \vec{v_2}
# + c_3 \exp(\lambda_3 t) \vec{v_3}
# \end{equation*}

# %%
# Solución del sistema
t = np.linspace(0, 3,  300)              # Rango de tiempo de integración

# Xsol=c1*np.exp(lambda1*t)*v1[0]+c2*np.exp(lambda2*t)*v2[0]+c3*np.exp(lambda3*t)*v3[0]
# Ysol=c1*np.exp(lambda1*t)*v1[1]+c2*np.exp(lambda2*t)*v2[1]+c3*np.exp(lambda3*t)*v3[1]
# Zsol=c1*np.exp(lambda1*t)*v1[2]+c2*np.exp(lambda2*t)*v2[2]+c3*np.exp(lambda3*t)*v3[2]


# Aplicamos las condiciones iniciales
# Xsol(0) = c1*b11 + c2*b12 + c3*b13 = 1
# Ysol(0) = c1*b21 + c2*b22 + c3*b23 = 0
# Zsol(0) = c1*b31 + c2*b32 + c3*b33 = 0


b11 = v1[0]
b12 = v2[0]
b13 = v3[0]
b21 = v1[1]
b22 = v2[1]
b23 = v3[1]
b31 = v1[2]
b32 = v2[2]
b33 = v3[2]

# %%
# Buscaremos los valores de c1,c2 y c3 que satisfacen las condiciones iniciales
# B1 [c1,c2,c3]^T = [1,0,0]^T
# [c11,c12,c13]^T = B1^{-1} [1,0,0]^T
# B1 es la matriz de los eigenvectores en las columnas
B1 = np.array([[b11, b12, b13], [b21, b22, b23], [b31, b32, b33]])

print('B1=', B1)
print(' ')


B1_inv = linalg.inv(B1)


print('B1_inv = [[B1_inv[0][0], B1_inv[0][1]], B1_inv[0][2]')
print('         [B1_inv[1][0], B1_inv[1][1]], B1_inv[1][2]')
print('         [B1_inv[2][0], B1_inv[2][1]], B1_inv[2][2]]')
print('B1_inv=', B1_inv)
print(' ')

X0 = np.array([[1,0,0]])

C = B1_inv@X0.T 

# Matriz de los coeficientes
C

c_1 = C[0]
c_2 = C[1]
c_3 = C[2]

print('Los coeficientes son:')
print('c_1=',c_1)
print('c_2=',c_2)
print('c_3=',c_3)

# Satisface las condiciones iniciales?
x1 = c_1*v1[0]+c_2*v2[0]+c_3*v3[0]
x2 = c_1*v1[1]+c_2*v2[1]+c_3*v3[1]
x3 = c_1*v1[2]+c_2*v2[2]+c_3*v3[2]

print('Condiciones iniciales: x(0),y(0),z(0): (1,0,0)', x1, x2, x3 )
# Out:
# B1= [[ 0.          0.          0.66666667]
#  [ 0.          1.         -0.66666667]
#  [ 1.          0.          0.33333333]]
#
# B1_inv = [[B1_inv[0][0], B1_inv[0][1]], B1_inv[0][2]
#          [B1_inv[1][0], B1_inv[1][1]], B1_inv[1][2]
#          [B1_inv[2][0], B1_inv[2][1]], B1_inv[2][2]]
# B1_inv= [[-0.5 -0.   1. ]
#  [ 1.   1.   0. ]
#  [ 1.5  0.   0. ]]
#
# Los coeficientes son:
# c_1= [-0.5]
# c_2= [1.]
# c_3= [1.5]
# Condiciones iniciales: x(0),y(0),z(0): (1,0,0) [1.] [0.] [0.]
